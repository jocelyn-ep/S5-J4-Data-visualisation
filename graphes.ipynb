# %% [markdown]
# # Projets : Des graphes, des graphes, des graphes, des graphes
#
# Objectif : compléter une série de katas pour tracer des graphes  🥋🥋
#
# Source : https://drive.google.com/file/d/1_zBTsqSe_a3JTvc7I-VZ2tJgogI0VFFl/view

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

dfBeautyProducts = pd.read_csv('company_sales_data.csv', on_bad_lines='skip', delimiter=",")

# %% [markdown]
# **Graphe 1**
#
# Réaliser un graphique avec deux axes. L'axe des abscisses va de 0 à 50 et s'intitule "Axe des x". L'axe des ordonnées s'intitule "Axe des y".
# Tracer la droite d'équation : x = 3y. Avec x allant de 0 à 50.
# Le graphe possède le titre suivant "Tracer une droite" et la droite est de couleur rouge.

# %%
#création des array x et y avec la fonction linspace
x = np.linspace(0,50,51)
y = x / 3 

#LINEPLOT : relation linéaire entre variables continues
plt.plot(x, y, color="r")   
plt.xlabel("Axe des x")
plt.ylabel("Axe des y")
plt.title("Tracer une droite")
plt.show()

# %% [markdown]
# **Graphe 2**
#
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.

# %%
#Courbe avec plt.plot
df = dfBeautyProducts

fig, ax = plt.subplots()
x = df['month_number']
y = df['total_profit']
ax.plot(x, y)   
plt.xlabel("Month")
plt.ylabel("Total profit (€)")
plt.title("Monthly total profit")
# définir les positions et les étiquettes des graduations de l'axe x
plt.xticks(range(min(x), max(x)+1, 1))

#Conertir 400000 en 400 000
# Créer la fonction de formatage
def format_y_axis(y, _):
    # Utiliser la méthode `format` pour insérer un espace tous les 3 chiffres
    return f"{y:,.0f}".replace(",", " ")
# Utiliser `FuncFormatter` pour appliquer la fonction de formatage à l'axe y
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# **Graphe 3**
#
# Ensuite, nous souhaitons un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps.
# Chaque courbe aura une couleur différente et nous souhaitons une légende qui indique quelle couleur correspond à quel produit.

# %%
#Courbe avec plt.plot. En partant du principe que profit = unité * 10
df = dfBeautyProducts
fig, ax = plt.subplots()
x = df['month_number']
y1 = df['facecream']*10
y2 = df['facewash']*10
y3 = df['toothpaste']*10
y4 = df['bathingsoap']*10
y5 = df['shampoo']*10
y6 = df['moisturizer']*10
ax.plot(x, y1, label="facecream")   
ax.plot(x, y2, label="facewash")   
ax.plot(x, y3, label="toothpaste")   
ax.plot(x, y4, label="bathingsoap")   
ax.plot(x, y5, label="shampoo")   
ax.plot(x, y6, label="moisturizer")   
plt.xlabel("Month")
plt.ylabel("Profit (€)")
plt.title("Monthly profit by product")

# définir les positions et les étiquettes des graduations de l'axe x
plt.xticks(range(min(x), max(x)+1, 1))

# Ajouter une légende
plt.legend()

#Conertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# **Graphe 4**
#
# Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit.
# A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par moi

# %%
#V1
#Histogramme groupé avec plt.bar
df = dfBeautyProducts
fig, ax = plt.subplots()
x = df['month_number']
y1 = df['facecream']
y2 = df['facewash']
y3 = df['toothpaste']
y4 = df['bathingsoap']
y5 = df['shampoo']
y6 = df['moisturizer']

# ax.bar(x,[y1,y2,y3,y4,y5,y6], stacked=True, label=["facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer"])
ax.bar(x, y1, label="facecream")   
ax.bar(x, y2, label="facewash")   
ax.bar(x, y3, label="toothpaste")   
ax.bar(x, y4, label="bathingsoap")   
ax.bar(x, y5, label="shampoo")   
ax.bar(x, y6, label="moisturizer")   


plt.xlabel("Month")
plt.ylabel("Units sold")
plt.title("Monthly profit by product")

# définir les positions et les étiquettes des graduations de l'axe x
plt.xticks(range(min(x), max(x)+1, 1))

# Ajouter une légende
plt.legend()

#Conertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
#V2
#Histogramme groupé avec plt.bar 
fig, ax = plt.subplots()
x = df['month_number']
y1 = df['facecream']
y2 = df['facewash']
y3 = df['toothpaste']
y4 = df['bathingsoap']
y5 = df['shampoo']
y6 = df['moisturizer']

largeurBarre = 0.15
ax.bar(x-3*(largeurBarre/2), y1, label="facecream", width = largeurBarre)   
ax.bar(x-2*(largeurBarre/2), y2, label="facewash", width = largeurBarre)   
ax.bar(x-(largeurBarre/2), y3, label="toothpaste", width = largeurBarre)   
ax.bar(x+(largeurBarre/2), y4, label="bathingsoap", width = largeurBarre)   
ax.bar(x+2*(largeurBarre/2), y5, label="shampoo", width = largeurBarre)   
ax.bar(x+3*(largeurBarre/2), y6, label="moisturizer", width = largeurBarre)   

plt.xlabel("Month")
plt.ylabel("Units sold")
plt.title("Monthly profit by product")

# définir les positions et les étiquettes des graduations de l'axe x
plt.xticks(range(min(x), max(x)+1, 1))

# Ajouter une légende
plt.legend()

#Conertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# **Graphe 5**
#
# Nous souhaitons un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée). Merci d'ajouter le pourcentage pour chaque produit.

# %%
#pie chart avec plt.pie

facecream = df['facecream'].sum()
facewash = df['facewash'].sum()
toothpaste = df['toothpaste'].sum()
bathingsoap = df['bathingsoap'].sum()
shampoo = df['shampoo'].sum()
moisturizer = df['moisturizer'].sum()


plt.pie([facecream,facewash,toothpaste,bathingsoap,shampoo,moisturizer], labels=["facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer"], autopct="%1.0f%%")
plt.title("Product contribution in annual total profit", fontsize=15)
plt.show()

# %% [markdown]
# **Graphe 6**
#
# Reprend donc les 3 fichiers csv qui donnent les ventes, la liste des clients et la liste des produits.
#
# D'abord, nous souhaitons avoir un graphe pie chart qui donne la répartition des produits par catégorie. Merci d'indiquer le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).

# %%
#import et nettoyage table customers
dfCustomers = pd.read_csv('customers.csv', on_bad_lines='skip', delimiter=",")
toDrop = dfCustomers.iloc[[2735,8494],:]
dfCustomers = dfCustomers.drop(toDrop.index)

#import et nettoyage table products
dfProducts = pd.read_csv('products.csv', on_bad_lines='skip', delimiter=",")
toDrop = dfProducts.iloc[[731],:]
dfProducts = dfProducts.drop(toDrop.index)

#import et nettoyage table transactions
dfTransactions = pd.read_csv('transactions.csv', on_bad_lines='skip', delimiter=",",)
dfTransactions = dfTransactions.drop_duplicates()

#création d'un grand df des ventes avec les jointures
dfSales = dfTransactions.merge(dfCustomers)
dfSales = dfSales.merge(dfProducts)

# %%
#pie chart avec plt.pie
prodRepByCat = dfProducts.groupby(['categ']).size()

plt.pie(prodRepByCat, labels=["category 0", "category 1", "category 2"],autopct="%1.0f%%")
plt.title("Product repartition among catalogue", fontsize=15)
plt.show()

# %% [markdown]
# **Graphe 7**
#
# Nous souhaitons un graphe qui donne l'évolution du CA pour chaque catégorie (en fonction du temps).

# %%
#Courbe avec plt.plot. En partant du principe que profit = unité * 10
df = dfSales
df['date'] = df['date'].str[:7].sort_values()

fig, ax = plt.subplots()
#j'élargis le graphe pour que l'axe des abcissses soit lisible
fig.set_size_inches(15,5)
x = df['date'].unique()
y1 = df.loc[df['categ'] == 0, :].groupby('date')['price'].sum ()
y2 = df.loc[df['categ'] == 1, :].groupby('date')['price'].sum ()
y3 = df.loc[df['categ'] == 2, :].groupby('date')['price'].sum ()
ax.plot(x, y1, label="category 0")   
ax.plot(x, y2, label="category 1")   
ax.plot(x, y3, label="category 2")    
plt.xlabel("Month")
plt.ylabel("Sales (€)")
plt.title("Monthly sales by product")
plt.legend()

#Convertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# **Graphe 8**
#
# Nous souhaitons un graphe qui donne un boxplot de la répartion des prix d'un produit pour chaque catégorie.
# En clair, le graphe montre 3 boxplots (un qui correspond à la catégorie 0, un à la catégorie 1 et un à la catégorie 2).

# %%
#BOX PLOT : boite à moustaches
df = dfProducts
priceDistri0 = df.loc[df['categ'] == 0, :]['price']
priceDistri1 = df.loc[df['categ'] == 1, :]['price']
priceDistri2 = df.loc[df['categ'] == 2, :]['price']
fig, ax = plt.subplots()
ax.boxplot([priceDistri0, priceDistri1, priceDistri2])
plt.ylabel("Price (€)")
plt.title("Product price box plot by category ")
# Ajouter une légende pour l'axe des abcisses. 
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Category 0', 'Category 1', 'Category2'])

plt.show()

# %% [markdown]
# **Graphe 9**
#
# Nous souhaitons un graphe qui donne la répartition du CA, pour chaque mois, en fonction du genre du client.

# %%
#Courbe avec plt.plot. 
df = dfSales
df['date'] = df['date'].str[:7].sort_values()

fig, ax = plt.subplots()
#j'élargis le graphe pour que l'axe des abcissses soit lisible
fig.set_size_inches(15,5)
x = df['date'].unique()
y1 = df.loc[df['sex'] == "m", :].groupby('date')['price'].sum ()
y2 = df.loc[df['sex'] == "f", :].groupby('date')['price'].sum ()
ax.plot(x, y1, label="male")   
ax.plot(x, y2, label="female")   
plt.xlabel("Month")
plt.ylabel("Sales (€)")
plt.title("Monthly sales by genre")
plt.legend()

#Convertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
#histo avec plt.bar
df = dfSales
df['date'] = df['date'].str[:7].sort_values()

fig, ax = plt.subplots()
#j'élargis le graphe pour que l'axe des abcissses soit lisible
fig.set_size_inches(15,5)
x = df['date'].unique()
y1 = df.loc[df['sex'] == "m", :].groupby('date')['price'].sum ()
y2 = df.loc[df['sex'] == "f", :].groupby('date')['price'].sum ()
bar1 = ax.bar(x, y1, label="male")   
bar2 = ax.bar(x, y2, label="female", bottom = y1)   

plt.xlabel("Month")
plt.ylabel("Sales (€)")
plt.title("Monthly sales by genre")
plt.legend()

#Convertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

# Ajout des étiquettes de pourcentage à l'intérieur des barres
repart1 = y1/(y1+y2)
repart2 = y2/(y1+y2)

for i in range(0,len(x)):
  ax.text(x[i],y1[i]/2, f'{repart1[i]*100:.0f}%', ha='center', color='white' )

for i in range(0,len(x)):
  ax.text(x[i], (y1[i]+y2[i]/2), f'{repart2[i]*100:.0f}%', ha='center', color='white' )


plt.show()

# %% [markdown]
# **Graphe 10**
#
# Nous souhaitons un graphe qui, pour chaque transaction, lie tranche d'âge du client et montant de la transaction.

# %%
#création de tranches d'âge
df = dfSales
df['age'] = 2022 - df['birth']
bins= [18,25,55,110]
labels = ['Young','Adult','Senior']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

#BOX PLOT : boite à moustaches
priceDistri0 = df.loc[df['age_group'] == "Young", :]['price']
priceDistri1 = df.loc[df['age_group'] == "Adult", :]['price']
priceDistri2 = df.loc[df['age_group'] == "Senior", :]['price']
fig, ax = plt.subplots()
ax.boxplot([priceDistri0, priceDistri1, priceDistri2])
plt.ylabel("Price (€)")
plt.title("Sale box plot by age group")
# Ajouter une légende pour l'axe des abcisses. 
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Young (18-24 yo)', 'Adult (25-54 yo)', 'Senior (55+ yo)'])

plt.show()

# %% [markdown]
# **Graphe 11**
#
# Nous souhaitons un graphe qui, pour chaque article, lie prix et nombre d'articles vendus pendant la période.

# %%
df = dfSales

x = df['price'].unique()
y = df['price'].value_counts()

fig, ax = plt.subplots()
#j'élargis le graphe pour que l'axe des abcissses soit lisible
fig.set_size_inches(15,5)
ax.scatter(x, y, marker='.')

plt.xlabel("Price (€)")
plt.ylabel("Units sold")
plt.title("Number of units sold by price during period 2021-04 to 2022-01")

#Convertir 10000 en 10 000 avec foonctionde formatage déjà défini plus haut
formatter = mtick.FuncFormatter(format_y_axis)
ax.yaxis.set_major_formatter(formatter)

# définir les positions et les étiquettes des graduations de l'axe x
plt.xticks(range(0, 310, 25))

plt.show()

# %% [markdown]
# **Graphe 12**
#
# Nous souhaitons un graphe qui donne la répartition du panier moyen (à chaque transaction).

# %%
df = dfSales
# Out:
#        id_prod     date session_id client_id sex  birth   price  categ  age  \
# 0       0_1483  2021-04    s_18746    c_4450   f   1977    4.99      0   45
# 1       0_1483  2021-12   s_140787    c_5433   f   1981    4.99      0   41
# 2       0_1483  2021-10   s_110736     c_857   m   1985    4.99      0   37
# 3       0_1483  2021-07    s_57626    c_3679   f   1989    4.99      0   33
# 4       0_1483  2021-09    s_92165    c_1609   m   1980    4.99      0   42
# ...        ...      ...        ...       ...  ..    ...     ...    ...  ...
# 336708  0_1920  2021-04    s_20115    c_7088   m   1987   25.16      0   35
# 336709  0_1920  2021-05    s_41465    c_7748   f   1989   25.16      0   33
# 336710    2_23  2021-09    s_96170    c_3976   f   1992  115.99      2   30
# 336711    2_28  2021-05    s_32812    c_7613   f   1993  103.50      2   29
# 336712    2_98  2021-03     s_3637    c_5967   f   2003  149.74      2   19
#
#        age_group
# 0          Adult
# 1          Adult
# ...
